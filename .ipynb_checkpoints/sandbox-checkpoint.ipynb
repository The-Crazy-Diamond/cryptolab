# %%
# %load_ext autoreload
# %autoreload 2
import cryptolab.ciphers.polyalphabetic as poly

poly.encrypt("sometext","key1","key2")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2
# 2
# 'key2'

# %%
import importlib
import cryptolab.ciphers.polyalphabetic as poly

importlib.reload(poly)

poly.encrypt("sometext", "key", "key","key")
# Out:
# 'rnlbsbws'

# %%
import importlib
import cryptolab.ciphers.polyalphabetic as mono

importlib.reload(mono)

mono.encrypt("sometext", "key")
# Out:
# 'rnlbsbws'
